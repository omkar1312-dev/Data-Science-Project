# %% [markdown]
# ## Importing All Libraries
# Data Preprocessing

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import os

# %% [markdown]
# Reding Data file

# %%
data = pd.read_csv('dataset.xlsx')
data.head()
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# 4                       Brain Development Course     0                50.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0        16.00  ...             1
# ...

# %% [markdown]
# calculating all columns and rows

# %%
data.shape   #117 rows and 28 columns
# Out:
# (117, 28)

# %% [markdown]
# To get basic information on the dataset , Nullvalues, data types, memory utilization.

# %%
data.info
# Out:
# <bound method DataFrame.info of      episode_number  pitch_number           brand_name  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %% [markdown]
# Finding Null Values

# %%
data.isna().sum()
# Out:
# episode_number           0
# pitch_number             0
# brand_name               0
# idea                     0
# deal                     0
# pitcher_ask_amount       0
# ask_equity               0
# ask_valuation            0
# deal_amount              0
# deal_equity              0
# deal_valuation           0
# ashneer_present          0
# anupam_present           0
# aman_present             0
# namita_present           0
# vineeta_present          0
# peyush_present           0
# ghazal_present           0
# ashneer_deal             0
# anupam_deal              0
# aman_deal                0
# namita_deal              0
# vineeta_deal             0
# peyush_deal              0
# ghazal_deal              0
# total_sharks_invested    0
# amount_per_shark         0
# equity_per_shark         0
# dtype: int64

# %% [markdown]
# Counting stastiscs values,max,min,mean,std, 25%,50%,75% values .

# %%
data.describe().T
# Out:
#                        count         mean           std      min     25%  \
# episode_number         117.0    18.735043     10.070778  1.00000   10.00
# pitch_number           117.0    59.000000     33.919021  1.00000   30.00
# deal                   117.0     0.555556      0.499041  0.00000    0.00
# pitcher_ask_amount     117.0   319.854709   2767.842777  0.00101   45.00
# ask_equity             117.0     5.188034      3.892121  0.25000    2.50
# ask_valuation          117.0  3852.462479  11931.601957  0.01000  666.67
# deal_amount            117.0    31.982915     36.687391  0.00000    0.00
# deal_equity            117.0     8.963504     13.106769  0.00000    0.00
# deal_valuation         117.0   467.104872    919.988864  0.00000    0.00
# ashneer_present        117.0     0.837607      0.370397  0.00000    1.00
# anupam_present         117.0     1.000000      0.000000  1.00000    1.00
# aman_present           117.0     0.837607      0.370397  0.00000    1.00
# ...

# %%
data[["pitcher_ask_amount","ask_equity","ask_valuation"]].agg([max,min,"mean"])
# Out:
#       pitcher_ask_amount  ask_equity  ask_valuation
# max         30000.000000   25.000000  120000.000000
# min             0.001010    0.250000       0.010000
# mean          319.854709    5.188034    3852.462479

# %% [markdown]
# Getting Columns

# %%
data.columns
# Out:
# Index(['episode_number', 'pitch_number', 'brand_name', 'idea', 'deal',
#        'pitcher_ask_amount', 'ask_equity', 'ask_valuation', 'deal_amount',
#        'deal_equity', 'deal_valuation', 'ashneer_present', 'anupam_present',
#        'aman_present', 'namita_present', 'vineeta_present', 'peyush_present',
#        'ghazal_present', 'ashneer_deal', 'anupam_deal', 'aman_deal',
#        'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal',
#        'total_sharks_invested', 'amount_per_shark', 'equity_per_shark'],
#       dtype='object')

# %% [markdown]
# Getting Company names

# %%
data['brand_name'].value_counts()
# Out:
# BluePine Industries    1
# Modern Myth            1
# Aliste Technologies    1
# Watt Technovations     1
# Theka Coffee           1
#                       ..
# LOKA                   1
# SweeDesi               1
# Auli Lifestyle         1
# Farda                  1
# Elcare India           1
# Name: brand_name, Length: 117, dtype: int64

# %%
data['deal'].value_counts()
# Out:
# 1    65
# 0    52
# Name: deal, dtype: int64

# %%
#maximum pitcher ask amount count
data[data['pitcher_ask_amount']==data['pitcher_ask_amount'].max()]
# Out:
#     episode_number  pitch_number  brand_name             idea  deal  \
# 30              11            31  Gopal's 56  Fiber Ice Cream     0
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 30             30000.0        25.0       120000.0          0.0          0.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 30  ...             0            0          0            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 30            0            0                      0               0.0
#
#     equity_per_shark
# 30               0.0
#
# [1 rows x 28 columns]

# %%
#maximum deal amount
data[data['deal_amount']==data['deal_amount'].max()]
# Out:
#     episode_number  pitch_number     brand_name        idea  deal  \
# 50              17            51  Aas Vidyalaya  EdTech App     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 50               150.0         3.0         5000.0        150.0         15.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 50  ...             1            0          0            1             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 50            1            0                      3              50.0
#
#     equity_per_shark
# 50               5.0
#
# [1 rows x 28 columns]

# %%
#maximum ask valuation 
data[data['ask_valuation']==data['ask_valuation'].max()]
# Out:
#     episode_number  pitch_number  brand_name             idea  deal  \
# 30              11            31  Gopal's 56  Fiber Ice Cream     0
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 30             30000.0        25.0       120000.0          0.0          0.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 30  ...             0            0          0            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 30            0            0                      0               0.0
#
#     equity_per_shark
# 30               0.0
#
# [1 rows x 28 columns]

# %%
#minimum ask equity
data[data['ask_equity']==data['ask_equity'].min()]
# Out:
#    episode_number  pitch_number   brand_name                     idea  deal  \
# 6               3             7  Qzense Labs  Food Freshness Detector     0
#
#    pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 6               100.0        0.25        40000.0          0.0          0.0
#
#    ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 6  ...             0            0          0            0             0
#
#    peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 6            0            0                      0               0.0
#
#    equity_per_shark
# 6               0.0
#
# [1 rows x 28 columns]

# %%
#maximum deal valuation
data[data['deal_valuation']==data['deal_valuation'].max()]
# Out:
#     episode_number  pitch_number   brand_name    idea  deal  \
# 12               5            13  Revamp Moto  E-Bike     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 12               100.0         1.0        10000.0        100.0          1.5
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 12  ...             0            1          1            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 12            0            0                      2              50.0
#
#     equity_per_shark
# 12              0.75
#
# [1 rows x 28 columns]

# %%
#deals done by the ashneer grover
ash_grover = data[data['ashneer_deal']==1]
ash_grover
# Out:
#      episode_number  pitch_number             brand_name  \
# 0                 1             1    BluePine Industries
# 1                 1             2          Booz scooters
# 3                 2             4             Tagz Foods
# 15                6            16            Skippi Pops
# 18                7            19     Raising Superstars
# 21                8            22           Beyond Snack
# 23                8            24          Motion Breeze
# 29               10            30              EventBeep
# 38               13            39        The Yarn Bazaar
# 45               16            46           Bamboo India
# 49               17            50  Find Your Kicks India
# 50               17            51          Aas Vidyalaya
# 55               18            56                   Otua
# 58               19            59                WeSTOCK
# 63               20            64               IN A CAN
# ...

# %%
#deals done by the  aman gupta
aman_gupta = data[data['aman_deal']==1]
aman_gupta
# Out:
#      episode_number  pitch_number             brand_name  \
# 0                 1             1    BluePine Industries
# 7                 3             8              Peeschute
# 11                4            12                 Bummer
# 12                5            13            Revamp Moto
# 15                6            16            Skippi Pops
# 18                7            19     Raising Superstars
# 21                8            22           Beyond Snack
# 24                9            25                  Altor
# 25                9            26                  Ariro
# 27               10            28                Nuutjob
# 28               10            29               Meatyour
# 29               10            30              EventBeep
# 32               11            33                  Farda
# 35               12            36                   LOKA
# 38               13            39        The Yarn Bazaar
# ...

# %%
#deals done by the namita thaper 
namita_thaper = data[data['namita_deal']==1]
namita_thaper
# Out:
#      episode_number  pitch_number             brand_name  \
# 11                4            12                 Bummer
# 15                6            16            Skippi Pops
# 16                6            17           Menstrupedia
# 24                9            25                  Altor
# 27               10            28                Nuutjob
# 32               11            33                  Farda
# 33               12            34         Auli Lifestyle
# 36               13            37                  Annie
# 39               14            40      The Renal Project
# 44               15            45                Cocofit
# 47               16            48           Beyond Water
# 49               17            50  Find Your Kicks India
# 50               17            51          Aas Vidyalaya
# 58               19            59                WeSTOCK
# 63               20            64               IN A CAN
# ...

# %%
# deals done by anupam mittal
anupam_mittal = data[data['anupam_deal']==1]
anupam_mittal
# Out:
#      episode_number  pitch_number                      brand_name  \
# 2                 1             3             Heart up my Sleeves
# 9                 4            10                           Cosiq
# 12                5            13                     Revamp Moto
# 15                6            16                     Skippi Pops
# 22                8            23  Vivalyf Innovations- Easy Life
# 28               10            29                        Meatyour
# 31               11            32        ARRCOAT Surface Textures
# 35               12            36                            LOKA
# 36               13            37                           Annie
# 37               13            38                       Caragreen
# 38               13            39                 The Yarn Bazaar
# 44               15            45                         Cocofit
# 45               16            46                    Bamboo India
# ...

# %%
# total number of deals done by each shark 
list = ['ashneer_deal','aman_deal','namita_deal','peyush_deal','anupam_deal','vineeta_deal','ghazal_deal']
data[list].sum()
# Out:
# ashneer_deal    21
# aman_deal       28
# namita_deal     22
# peyush_deal     27
# anupam_deal     24
# vineeta_deal    15
# ghazal_deal      7
# dtype: int64

# %%
# number of episodes each shark present
list1 = ['ashneer_present','anupam_present','aman_present','namita_present','vineeta_present','peyush_present','ghazal_present']
data[list1].sum()
# Out:
# ashneer_present     98
# anupam_present     117
# aman_present        98
# namita_present     106
# vineeta_present     66
# peyush_present      88
# ghazal_present      26
# dtype: int64

# %%
eqt = data.groupby('peyush_deal')['equity_per_shark'].sum().loc[1]
amt = data.groupby('peyush_deal')['amount_per_shark'].sum().loc[1]
print(eqt,'%')
print(amt,"lakhs")
# Out:
# 315.85 %
# 719.666919163 lakhs

# %%
# Total Amount Invested By shark
eqt = data.groupby('ashneer_deal')['equity_per_shark'].sum().loc[1]
amt = data.groupby('ashneer_deal')['amount_per_shark'].sum().loc[1]
print(eqt,'%')
print(amt,"lakhs")
# Out:
# 93.249999999 %
# 494.33333333 lakhs

# %%
# Invested by vineeta and Equity
eqt = data.groupby('vineeta_deal')['equity_per_shark'].sum().loc[1]
amt = data.groupby('vineeta_deal')['amount_per_shark'].sum().loc[1]
print(eqt,'%')
print(amt,"lakhs")
# Out:
# 131.533333333 %
# 328.33333333 lakhs

# %%
# invested by anupam and equity
eqt = data.groupby('anupam_deal')['equity_per_shark'].sum().loc[1]
amt = data.groupby('anupam_deal')['amount_per_shark'].sum().loc[1]
print(eqt,'%')
print(amt,"lakhs")
# Out:
# 166.35 %
# 533.83360253 lakhs

# %%
# Invested By aman and its equity
eqt = data.groupby('aman_deal')['equity_per_shark'].sum().loc[1]
amt = data.groupby('aman_deal')['amount_per_shark'].sum().loc[1]
print(eqt,'%')
print(amt,"lakhs")
# Out:
# 160.263333334 %
# 887.500016693 lakhs

# %%
eqt = data.groupby('ghazal_deal')['equity_per_shark'].sum().loc[1]
amt = data.groupby('ghazal_deal')['amount_per_shark'].sum().loc[1]
print(eqt,'%')
print(amt,"lakhs")
# Out:
# 46.7 %
# 130.00025250000002 lakhs

# %% [markdown]
# ## Data Visualization

# %%
aman_present=len(data[data.aman_present==1])
anupam_present=len(data[data.anupam_present==1])
ashneer_present=len(data[data.ashneer_present==1])
ghazal_present=len(data[data.ghazal_present==1])
namita_present=len(data[data.namita_present==1])
peyush_present=len(data[data.peyush_present==1])
vineeta_present=len(data[data.vineeta_present==1])

# %%
fig =plt.figure(figsize=(7,5))
present=[aman_present,anupam_present,ashneer_present,ghazal_present,namita_present,peyush_present,vineeta_present]
names=['Aman','Anupam','Ashneer','Ghazal','Namita','Peyush','Vineeta']
plt.bar(names,present, color = 'slateblue',width=0.5)
plt.xlabel("Sharks")
plt.ylabel("Sharks Present")
plt.title("Sharks Present Vs Name")
plt.show()

# %%
plt.pie(present,labels=names,radius=1.5,autopct='%0.1f%%')
explode = [0.25,0.25,0.25,0.25,0.25,0.25,0.25]
plt.show()

# %%
aman_invested=len(data[data.aman_deal==1])
anupam_invested=len(data[data.anupam_deal==1])
ashneer_invested=len(data[data.ashneer_deal==1])
ghazal_invested=len(data[data.ghazal_deal==1])
namita_invested=len(data[data.namita_deal==1])
peyush_invested=len(data[data.peyush_deal==1])
vineeta_invested=len(data[data.vineeta_deal==1])

# %%
#In how many company they invested
fig =plt.figure(figsize=(10,5))
invested=[aman_invested,anupam_invested,ashneer_invested,ghazal_invested,namita_invested,peyush_invested,vineeta_invested]
names=['Aman','Anupam','Ashneer','Ghazal','Namita','Peyush','Vineeta']
plt.bar(names,invested,color='green',width=0.5)
plt.xlabel("Sharks Name")
plt.ylabel("Sharks Invested")
plt.title("Sharks Invested vs Name")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.countplot(x='total_sharks_invested',data=data)
plt.show()

# %%
#No. of brands the sharks have invested:
num_deal_shark=[data.ashneer_deal.sum(), data.anupam_deal.sum(), data.aman_deal.sum(), data.namita_deal.sum(), data.vineeta_deal.sum(), data.peyush_deal.sum(), data.ghazal_deal.sum()]
all_sharks=["Ashneer", "Anupam", "Aman", "Namita", "Vineeta", "Peyush", "Ghazal"]
figure=px.bar(all_sharks, x=all_sharks, y=num_deal_shark,title="Number of deals done by individual shark:",color=all_sharks,text_auto=True)
figure.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Season 1 of Shark Tank India had 117 pitches. Anupam was the only one who appeared in every episode. Out of 117 proposals, 65 received funded. Aman has invested in 28 firms, the most of any shark.
# Thank you.
